# %%
#!pip install folium
#!pip install requests
#!pip install pandas
#!pip install numpy
#!pip install matplotlib
#!pip install seaborn
#!pip install scikit-learn
# Out:
# Requirement already satisfied: folium in c:\users\berber\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: xyzservices in c:\users\berber\anaconda3\lib\site-packages (from folium) (2023.10.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\berber\anaconda3\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: requests in c:\users\berber\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\berber\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\berber\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\berber\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\berber\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\berber\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\berber\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\berber\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: requests in c:\users\berber\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\berber\anaconda3\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\berber\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\berber\anaconda3\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\berber\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: pandas in c:\users\berber\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\berber\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\berber\anaconda3\lib\site-packages (from pandas) (2023.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\berber\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\berber\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\berber\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\berber\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\berber\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\berber\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\berber\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\berber\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\berber\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\berber\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\berber\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\berber\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2023.2)
# Requirement already satisfied: six>=1.5 in c:\users\berber\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\berber\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\berber\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\berber\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\berber\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\berber\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import folium
import requests
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# # “Cold Start” - Restaurants Recommendation Location-Based

# %% [markdown]
# ##### This project presents a solution to the user cold-start problem in recommender systems by implementing geographic clustering methods on Yelp restaurant data.
# ##### The "cold-start" problem, is where new users without prior activity or preferences pose a challenge in delivering personalized and relevant recommendations. Traditional approaches relying on
# ##### historical data fall short for these users, emphasizing the need for innovative solutions. Our project aims to address this issue using geospatial data available within Yelp's extensive collection of restaurant information.
# ##### We will examine 3 clustering methods:K-Means Clustering, DBSCAN and Hierarchical Clustering and use them as a basis for creating location-based recommendations.

# %% [markdown]
# ### Collecting Data

# %% [markdown]
# ##### API KEY= to try this code you will need to inser your API KEY from Yelp. for help: https://docs.developer.yelp.com/docs/getting-started.
# The Search API endpoint returns up to 1,000 results from the original query and up to 50 results per individual Search API request. Hence, we used an offset parameter to get the next page of results.
# To use the offset parameter, if is specified limit=50 we'll get results 1 through 50. Further, if is specified offset=51 we'll get results 51 through 100.
# ##### Specific location - Texas.
# - Due to the restrictions on the amount of data entries we could retrieve, we chose to concentrate on collecting information from a single city - Texas.
# This approach allowed us to gather a data set that was both extensive and relevant to our project's needs.
# - we chose to focus on Texas because we think it has strategic advantages:
# Texas has one of the largest and fastest-growing economies in the U.S., providing business opportunities across a range of sectors.
# With a mix of urban and rural areas and a culturally rich demographic, Texas offers a varied market for consumers.

# %%
# empty list to place our data for each page
lst = []
API_KEY = "Enter Your API KEY"
# our offset parameter - each page 50 rows
offset = 0
print('initial offset number: {}'.format(offset))

# loop through the api 20 times (limit is 1000 rows with each page includes 50 rows)
for i in range(20):
    
    try:
        headers = {'Authorization': 'Bearer {}'.format(API_KEY)}
        search_api_url = 'https://api.yelp.com/v3/businesses/search'
        params = {'term': 'food', 
                  'categories': 'restaurants',
                  'location': 'Texas', #If we will change here we can do the project on a different city
                  'offset': offset,
                  'limit': 50}

        response = requests.get(search_api_url, 
                                headers=headers, 
                                params=params, 
                                timeout=10)

        # return a dictionary
        data_dict = response.json()
        
        # convert the business dictionary to a pandas dataframe and append to list
        data = pd.DataFrame(data_dict['businesses'])
        lst.append(data)
      
        # add 50 to the offset to access a new page
        offset += 50
        print('current offset number: {}'.format(offset))
        
    except Exception as ex:
        print('exception: {}\nexit loop.'.format(ex))
        break

# concatenate all pages to one dataframe and reset index
df = pd.concat(lst)
df = df.reset_index(drop=True)

# review shape of dataframe
rows, columns = df.shape
print()
print('query includes {:,} rows and {} columns.'.format(rows, columns))
print('row id is unique: {}.'.format(df['id'].is_unique))

# review if dataframe id is unique, if not drop duplicates
if df['id'].is_unique == False:
    duplicates = df.loc[df.duplicated(subset=['id'])]
    vals = list(duplicates.head()['name'].values)
    print('\nduplicates found: {}.'.format(vals))
    
    df = df.drop_duplicates(subset=['id']).reset_index(drop=True)
    print('dropping duplicates...')
    
    rows, columns = df.shape
    print('\nrow id is unique: {}.'.format(df['id'].is_unique))
    print('query includes {:,} rows and {} columns.'.format(rows, columns))
# Out:
# initial offset number: 0
# current offset number: 50
# current offset number: 100
# current offset number: 150
# current offset number: 200
# current offset number: 250
# current offset number: 300
# current offset number: 350
# current offset number: 400
# current offset number: 450
# current offset number: 500
# current offset number: 550
# current offset number: 600
# current offset number: 650
# current offset number: 700
# current offset number: 750
# current offset number: 800
# current offset number: 850
# current offset number: 900
# current offset number: 950
# current offset number: 1000
#
# query includes 1,000 rows and 16 columns.
# row id is unique: False.
#
# duplicates found: ['Local Foods', 'Red’s Kitchen', 'Tacos La Sultana', 'Jun', 'Cantina Barba'].
# dropping duplicates...
#
# row id is unique: True.
# query includes 853 rows and 16 columns.

# %%
df.head()
# Out:
#                        id                         alias                name  \
# 0  NNMvUp-r7sQt7Q2l-kO9wA  the-breakfast-klub-houston-2  The Breakfast Klub
# 1  xdx57Qj1FJi0MK8kwzbeuA     la-calle-tacos-houston-16      La Calle Tacos
# 2  MuqrcFUxtovR-0Z4rlSwwg     space-city-birria-houston   Space City Birria
# 3  RoU8KznQMrRFcIjYVtdZMw          the-pit-room-houston        The Pit Room
# 4  n8MvjjhuUg8NAQKinUASHw      underground-hall-houston    Underground Hall
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1  https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2  https://www.yelp.com/biz/space-city-birria-hou...           180
# 3  https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4  https://www.yelp.com/biz/underground-hall-hous...           132
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4  [{'alias': 'food_court', 'title': 'Food Court'...     4.4
#
#                                          coordinates  \
# 0     {'latitude': 29.73843, 'longitude': -95.38048}
# 1  {'latitude': 29.7634662971423, 'longitude': -9...
# 2  {'latitude': 29.7623351, 'longitude': -95.3630...
# 3  {'latitude': 29.7342352703345, 'longitude': -9...
# 4     {'latitude': 29.76038, 'longitude': -95.36162}
#
#                                  transactions price  \
# 0                          [pickup, delivery]    $$
# 1                          [pickup, delivery]    $$
# 2  [restaurant_reservation, pickup, delivery]    $$
# 3                          [pickup, delivery]    $$
# 4                                  [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '3711 Travis St', 'address2': '',...  +17135288561
# 1  {'address1': '909 Franklin St', 'address2': ''...  +18327358226
# 2  {'address1': '415 Milam St', 'address2': None,...  +18328027333
# 3  {'address1': '1201 Richmond Ave', 'address2': ...  +12818881929
# 4  {'address1': '1010 Prairie St', 'address2': No...  +12818884323
#
#     display_phone     distance
# 0  (713) 528-8561  3370.053899
# 1  (832) 735-8226    86.248358
# 2  (832) 802-7333   355.968253
# 3  (281) 888-1929  4585.949511
# 4  (281) 888-4323   351.703073

# %%
# Specify the file path where you want to save the Excel file
excel_file_path = 'Yelp_data.xlsx'

# Export DataFrame to Excel
df.to_excel(excel_file_path, index=False)  # Set index=False if you don't want the DataFrame index in the Excel file

# %%
# Read the Excel file into a DataFrame
df = pd.read_excel(excel_file_path)
df.head()
# Out:
#                        id                         alias                name  \
# 0  NNMvUp-r7sQt7Q2l-kO9wA  the-breakfast-klub-houston-2  The Breakfast Klub
# 1  xdx57Qj1FJi0MK8kwzbeuA     la-calle-tacos-houston-16      La Calle Tacos
# 2  MuqrcFUxtovR-0Z4rlSwwg     space-city-birria-houston   Space City Birria
# 3  RoU8KznQMrRFcIjYVtdZMw          the-pit-room-houston        The Pit Room
# 4  n8MvjjhuUg8NAQKinUASHw      underground-hall-houston    Underground Hall
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1  https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2  https://www.yelp.com/biz/space-city-birria-hou...           180
# 3  https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4  https://www.yelp.com/biz/underground-hall-hous...           132
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4  [{'alias': 'food_court', 'title': 'Food Court'...     4.4
#
#                                          coordinates  \
# 0     {'latitude': 29.73843, 'longitude': -95.38048}
# 1  {'latitude': 29.7634662971423, 'longitude': -9...
# 2  {'latitude': 29.7623351, 'longitude': -95.3630...
# 3  {'latitude': 29.7342352703345, 'longitude': -9...
# 4     {'latitude': 29.76038, 'longitude': -95.36162}
#
#                                        transactions price  \
# 0                            ['pickup', 'delivery']    $$
# 1                            ['pickup', 'delivery']    $$
# 2  ['restaurant_reservation', 'pickup', 'delivery']    $$
# 3                            ['pickup', 'delivery']    $$
# 4                                      ['delivery']    $$
#
#                                             location         phone  \
# 0  {'address1': '3711 Travis St', 'address2': '',...  1.713529e+10
# 1  {'address1': '909 Franklin St', 'address2': ''...  1.832736e+10
# 2  {'address1': '415 Milam St', 'address2': None,...  1.832803e+10
# 3  {'address1': '1201 Richmond Ave', 'address2': ...  1.281888e+10
# 4  {'address1': '1010 Prairie St', 'address2': No...  1.281888e+10
#
#     display_phone     distance
# 0  (713) 528-8561  3370.053899
# 1  (832) 735-8226    86.248358
# 2  (832) 802-7333   355.968253
# 3  (281) 888-1929  4585.949511
# 4  (281) 888-4323   351.703073

# %% [markdown]
# ### Pre Processing
# #### Data preprocessing is a foundational task that enhances the quality and precision of the dataset, ensuring that the subsequent analysis is based on reliable and relevant information

# %% [markdown]
# ##### - Creating columns of latitude and longitude from column "coordinates".

# %%
# Define a function to extract latitude and longitude from coordinates dictionary
def extract_coordinates(coordinates):
    try:
        coordinates_dict = eval(coordinates)  # Convert string representation of dictionary to actual dictionary
        return pd.Series({'latitude': coordinates_dict['latitude'], 'longitude': coordinates_dict['longitude']})
    except:
        return pd.Series({'latitude': None, 'longitude': None})  # Return None for missing or malformed data

# Apply the extract_coordinates function to the "coordinates" column
df[['latitude', 'longitude']] = df['coordinates'].apply(extract_coordinates)

# Drop the original "coordinates" column
df = df.drop(columns=['coordinates'])

# Display the DataFrame
df.head()
# Out:
#                        id                         alias                name  \
# 0  NNMvUp-r7sQt7Q2l-kO9wA  the-breakfast-klub-houston-2  The Breakfast Klub
# 1  xdx57Qj1FJi0MK8kwzbeuA     la-calle-tacos-houston-16      La Calle Tacos
# 2  MuqrcFUxtovR-0Z4rlSwwg     space-city-birria-houston   Space City Birria
# 3  RoU8KznQMrRFcIjYVtdZMw          the-pit-room-houston        The Pit Room
# 4  n8MvjjhuUg8NAQKinUASHw      underground-hall-houston    Underground Hall
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1  https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2  https://www.yelp.com/biz/space-city-birria-hou...           180
# 3  https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4  https://www.yelp.com/biz/underground-hall-hous...           132
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4  [{'alias': 'food_court', 'title': 'Food Court'...     4.4
#
#                                        transactions price  \
# 0                            ['pickup', 'delivery']    $$
# 1                            ['pickup', 'delivery']    $$
# 2  ['restaurant_reservation', 'pickup', 'delivery']    $$
# 3                            ['pickup', 'delivery']    $$
# 4                                      ['delivery']    $$
#
#                                             location         phone  \
# 0  {'address1': '3711 Travis St', 'address2': '',...  1.713529e+10
# 1  {'address1': '909 Franklin St', 'address2': ''...  1.832736e+10
# 2  {'address1': '415 Milam St', 'address2': None,...  1.832803e+10
# 3  {'address1': '1201 Richmond Ave', 'address2': ...  1.281888e+10
# 4  {'address1': '1010 Prairie St', 'address2': No...  1.281888e+10
#
#     display_phone     distance   latitude  longitude
# 0  (713) 528-8561  3370.053899  29.738430 -95.380480
# 1  (832) 735-8226    86.248358  29.763466 -95.360690
# 2  (832) 802-7333   355.968253  29.762335 -95.363033
# 3  (281) 888-1929  4585.949511  29.734235 -95.393968
# 4  (281) 888-4323   351.703073  29.760380 -95.361620

# %% [markdown]
# ##### - For each branch of restaurant create column with the address (addresses are in column "location").

# %%
# Define a function to extract addresses from the 'location' column
def extract_address(location, idx):
    try:
        location_dict = eval(location)  # Convert string representation of dictionary to actual dictionary
        return location_dict.get(f'address{idx}', None)
    except:
        return None  # Return None if location data is missing or malformed

# Determine the maximum number of addresses
max_num_addresses = df['location'].apply(lambda x: len(eval(x)) if isinstance(x, str) else 0).max()

# Extract addresses for each row
for i in range(1, max_num_addresses + 1):
    col_name = f'Address {i}'
    df[col_name] = df['location'].apply(lambda x: extract_address(x, i))

# Drop the original 'location' column
df = df.drop(columns=['location'])

# Display the DataFrame
df.head()
# Out:
#                        id                         alias                name  \
# 0  NNMvUp-r7sQt7Q2l-kO9wA  the-breakfast-klub-houston-2  The Breakfast Klub
# 1  xdx57Qj1FJi0MK8kwzbeuA     la-calle-tacos-houston-16      La Calle Tacos
# 2  MuqrcFUxtovR-0Z4rlSwwg     space-city-birria-houston   Space City Birria
# 3  RoU8KznQMrRFcIjYVtdZMw          the-pit-room-houston        The Pit Room
# 4  n8MvjjhuUg8NAQKinUASHw      underground-hall-houston    Underground Hall
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1  https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2  https://www.yelp.com/biz/space-city-birria-hou...           180
# 3  https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4  https://www.yelp.com/biz/underground-hall-hous...           132
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4  [{'alias': 'food_court', 'title': 'Food Court'...     4.4
#
#                                        transactions  ...   latitude  \
# 0                            ['pickup', 'delivery']  ...  29.738430
# 1                            ['pickup', 'delivery']  ...  29.763466
# 2  ['restaurant_reservation', 'pickup', 'delivery']  ...  29.762335
# 3                            ['pickup', 'delivery']  ...  29.734235
# 4                                      ['delivery']  ...  29.760380
#
#    longitude          Address 1  Address 2  Address 3  Address 4 Address 5  \
# 0 -95.380480     3711 Travis St                             None      None
# 1 -95.360690    909 Franklin St                             None      None
# 2 -95.363033       415 Milam St       None       None       None      None
# 3 -95.393968  1201 Richmond Ave                             None      None
# 4 -95.361620    1010 Prairie St       None                  None      None
#
#   Address 6 Address 7 Address 8
# 0      None      None      None
# 1      None      None      None
# 2      None      None      None
# 3      None      None      None
# 4      None      None      None
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### - Counting empty cells and treatment.

# %%
none_count = df.isna().sum()
print(none_count)
# Out:
# id                 0
# alias              0
# name               0
# image_url          4
# is_closed          0
# url                0
# review_count       0
# categories         0
# rating             0
# transactions       0
# price            297
# phone             83
# display_phone     83
# distance           0
# latitude           0
# longitude          0
# Address 1         11
# Address 2        211
# Address 3        365
# Address 4        853
# Address 5        853
# Address 6        853
# Address 7        853
# Address 8        853
# dtype: int64

# %%
# Remove columns 'address_4', 'address_5', 'address_6', 'address_7', 'address_8' if they exist
df = df.drop(columns=['Address 4', 'Address 5', 'Address 6', 'Address 7','Address 8'])
df.head()
# Out:
#                        id                         alias                name  \
# 0  NNMvUp-r7sQt7Q2l-kO9wA  the-breakfast-klub-houston-2  The Breakfast Klub
# 1  xdx57Qj1FJi0MK8kwzbeuA     la-calle-tacos-houston-16      La Calle Tacos
# 2  MuqrcFUxtovR-0Z4rlSwwg     space-city-birria-houston   Space City Birria
# 3  RoU8KznQMrRFcIjYVtdZMw          the-pit-room-houston        The Pit Room
# 4  n8MvjjhuUg8NAQKinUASHw      underground-hall-houston    Underground Hall
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1  https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2  https://www.yelp.com/biz/space-city-birria-hou...           180
# 3  https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4  https://www.yelp.com/biz/underground-hall-hous...           132
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4  [{'alias': 'food_court', 'title': 'Food Court'...     4.4
#
#                                        transactions price         phone  \
# 0                            ['pickup', 'delivery']    $$  1.713529e+10
# 1                            ['pickup', 'delivery']    $$  1.832736e+10
# 2  ['restaurant_reservation', 'pickup', 'delivery']    $$  1.832803e+10
# 3                            ['pickup', 'delivery']    $$  1.281888e+10
# 4                                      ['delivery']    $$  1.281888e+10
#
#     display_phone     distance   latitude  longitude          Address 1  \
# 0  (713) 528-8561  3370.053899  29.738430 -95.380480     3711 Travis St
# 1  (832) 735-8226    86.248358  29.763466 -95.360690    909 Franklin St
# 2  (832) 802-7333   355.968253  29.762335 -95.363033       415 Milam St
# 3  (281) 888-1929  4585.949511  29.734235 -95.393968  1201 Richmond Ave
# 4  (281) 888-4323   351.703073  29.760380 -95.361620    1010 Prairie St
#
#   Address 2 Address 3
# 0
# 1
# 2      None      None
# 3
# 4      None

# %% [markdown]
# ##### - Validate only open restaurants will show.

# %%
df.dtypes
df['is_closed'] = (df['is_closed'] == False).astype(int)
df
# Out:
#                          id                               alias  \
# 0    NNMvUp-r7sQt7Q2l-kO9wA        the-breakfast-klub-houston-2
# 1    xdx57Qj1FJi0MK8kwzbeuA           la-calle-tacos-houston-16
# 2    MuqrcFUxtovR-0Z4rlSwwg           space-city-birria-houston
# 3    RoU8KznQMrRFcIjYVtdZMw                the-pit-room-houston
# 4    n8MvjjhuUg8NAQKinUASHw            underground-hall-houston
# ..                      ...                                 ...
# 848  omLp9cc9_OZ9HxE3NLwoOA         cabo-bobs-burritos-stafford
# 849  mXDuUUo-7y-QX2kHib7anw                  mr-hoagies-houston
# 850  -oppmYj5EqXG3qGumptLXA  kura-revolving-sushi-bar-houston-3
# 851  7ajDcDGFgwnaKE1wdht4HQ    figata-crafted-paninis-houston-2
# 852  HoQsF_27CA8-iMU4eOUeUw               pho-saigon-houston-12
#
#                          name  \
# 0          The Breakfast Klub
# 1              La Calle Tacos
# 2           Space City Birria
# 3                The Pit Room
# 4            Underground Hall
# ..                        ...
# 848       Cabo Bob's Burritos
# 849               Mr Hoagie's
# 850  Kura Revolving Sushi Bar
# 851    Figata Crafted Paninis
# 852                Pho Saigon
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/g8NDOI...          1
# 1    https://s3-media4.fl.yelpcdn.com/bphoto/kBz7FT...          1
# 2    https://s3-media2.fl.yelpcdn.com/bphoto/V3Uh6j...          1
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/KkligA...          1
# 4    https://s3-media3.fl.yelpcdn.com/bphoto/feu0KK...          1
# ..                                                 ...        ...
# 848  https://s3-media1.fl.yelpcdn.com/bphoto/wSlhJC...          1
# 849  https://s3-media2.fl.yelpcdn.com/bphoto/pCBZES...          1
# 850  https://s3-media2.fl.yelpcdn.com/bphoto/vKPF5E...          1
# 851  https://s3-media2.fl.yelpcdn.com/bphoto/doqCy-...          1
# 852  https://s3-media4.fl.yelpcdn.com/bphoto/FEDVpP...          1
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/the-breakfast-klub-ho...          6099
# 1    https://www.yelp.com/biz/la-calle-tacos-housto...          1153
# 2    https://www.yelp.com/biz/space-city-birria-hou...           180
# 3    https://www.yelp.com/biz/the-pit-room-houston?...          2910
# 4    https://www.yelp.com/biz/underground-hall-hous...           132
# ..                                                 ...           ...
# 848  https://www.yelp.com/biz/cabo-bobs-burritos-st...            54
# 849  https://www.yelp.com/biz/mr-hoagies-houston?ad...           130
# 850  https://www.yelp.com/biz/kura-revolving-sushi-...           527
# 851  https://www.yelp.com/biz/figata-crafted-panini...             8
# 852  https://www.yelp.com/biz/pho-saigon-houston-12...          1161
#
#                                             categories  rating  \
# 0    [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1    [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
# 2    [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.6
# 3    [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.3
# 4    [{'alias': 'food_court', 'title': 'Food Court'...     4.4
# ..                                                 ...     ...
# 848         [{'alias': 'mexican', 'title': 'Mexican'}]     4.2
# 849  [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.5
# 850  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.8
# 851  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     5.0
# 852  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.9
#
#                                          transactions price         phone  \
# 0                              ['pickup', 'delivery']    $$  1.713529e+10
# 1                              ['pickup', 'delivery']    $$  1.832736e+10
# 2    ['restaurant_reservation', 'pickup', 'delivery']    $$  1.832803e+10
# 3                              ['pickup', 'delivery']    $$  1.281888e+10
# 4                                        ['delivery']    $$  1.281888e+10
# ..                                                ...   ...           ...
# 848                                                []   NaN           NaN
# 849                                        ['pickup']     $  1.281440e+10
# 850                            ['delivery', 'pickup']    $$  1.713636e+10
# 851                            ['delivery', 'pickup']   NaN  1.346967e+10
# 852                            ['delivery', 'pickup']    $$  1.713524e+10
#
#       display_phone      distance   latitude  longitude          Address 1  \
# 0    (713) 528-8561   3370.053899  29.738430 -95.380480     3711 Travis St
# 1    (832) 735-8226     86.248358  29.763466 -95.360690    909 Franklin St
# 2    (832) 802-7333    355.968253  29.762335 -95.363033       415 Milam St
# 3    (281) 888-1929   4585.949511  29.734235 -95.393968  1201 Richmond Ave
# 4    (281) 888-4323    351.703073  29.760380 -95.361620    1010 Prairie St
# ..              ...           ...        ...        ...                ...
# 848             NaN  24113.415560  29.648874 -95.572170      11940 SW Frwy
# 849  (281) 440-1988  29061.398869  30.009459 -95.460355  2040 Fm 1960 Rd W
# 850  (713) 636-2696   3159.185802  29.739773 -95.378758       3510 Main St
# 851  (346) 966-5284    351.703073  29.760380 -95.361620    1010 Prairie St
# 852  (713) 524-3734   2607.418312  29.745129 -95.377408      2808 Milam St
#
#     Address 2         Address 3
# 0
# 1
# 2        None              None
# 3
# 4        None
# ..        ...               ...
# 848      None
# 849
# 850                        None
# 851            Underground Hall
# 852
#
# [853 rows x 19 columns]

# %% [markdown]
# ### Visualizations
# #### Data visualization during preprocessing is essential for quickly spotting trends, anomalies, and inconsistencies.

# %% [markdown]
# ##### - Show the best restaurants in Texas.

# %%
top_restaurants = df.sort_values(by=['review_count', 'rating'], ascending=False)[:10]
fig, ax = plt.subplots(figsize=(7,7))
sns.barplot(x = 'rating', y = 'name', data=top_restaurants, ax= ax)
plt.show()

# %% [markdown]
# ##### - Show the relationship between rating & number of reviews.

# %%
plt.figure(figsize=(7, 7))
plt.scatter(df['rating'], df['review_count'], alpha=0.5)  # Switched x and y variables
plt.title('Restaurant Rating vs Number of Reviews (Switched Axes)')
plt.xlabel('Rating')  # Rating on the x-axis
plt.ylabel('Number of Reviews')  # Number of reviews on the y-axis
plt.grid(True)
plt.show()

# %% [markdown]
# most restaurants have max 2000 reviews.
# lets zoom-in an:

# %%
plt.figure(figsize=(7, 7))
plt.scatter(df['rating'], df['review_count'], alpha=0.5)  # Switched x and y variables
plt.title('Restaurant Rating vs Number of Reviews (Switched Axes)')
plt.xlabel('Rating')  # Rating on the x-axis
plt.ylabel('Number of Reviews')  # Number of reviews on the y-axis
plt.grid(True)
# Set x-axis limits to 0-2000
plt.ylim(0, 2000)
plt.show()

# %% [markdown]
# - Most of the restaurants' rating are 3.5-5, and with top of 250 reviews - suggesting a trend towards higher customer satisfaction.
# - There are also restaurands with more reviews, and most of them have rating around 4 - indicating that establishments with greater review counts often deliver quality experiences consistently enough to maintain a high rating.

# %% [markdown]
# ##### - Show the restaurant rating distribution.

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['rating'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Restaurant Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# - There are more rating of 4 than 5 - suggesting that while customers are generally satisfied, they may reserve the highest rating for exceptional experiences.
# - It is not common to rate if its not 3+ - implies that customers are less likely to rate their experience unless it meets a baseline level of satisfaction.

# %% [markdown]
# ##### - Show the restaurant dennsity & rating by location.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='longitude', y='latitude', size='rating', data=df, hue='rating', palette='viridis')
plt.title('Restaurant Density and Ratings')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Rating')
plt.show()

# %% [markdown]
# - Most of the restaurants locate in the range- lat: (29.7-29.8), lon: (-95.6,-95.3) - Houston in texas is a significant urban center.
# - As shows in the other graph also here we can see the common rating of 4 and 5.
# - most of the low rating are in the center (where is the most restaurants located) - could imply that competition is stiffer, or that quality may vary more significantly where restaurant options are abundant.

# %% [markdown]
# ### Clustering & Recommendation Models
# ##### We propose a geospatial clustering approach, using: K-means clustering, DBSCAN and hierarchical clustering.
# ##### For each clustering method we will exam the Silhouette Score to asses the model.
# ##### This clusters will be a foundation for delivering recommendations to users.
# ##### Experimental framework:
# - valuate the models's accuracy in clustering restaurants geographically.
# - assess the system's effectiveness at recommending high-rated restaurants within these clusters.
# - measure the speed at which these recommendations are generated.

# %% [markdown]
# #### Create Case-Study data to exam the models

# %%
test = {
    'longitude': [],
    'latitude': []
}
# Fixing longitude and latitude values
test['longitude'] = [29.7137]
test['latitude'] = [-95.3892]
# Creating DataFrame
user = pd.DataFrame(test)
user
# Out:
#    longitude  latitude
# 0    29.7137  -95.3892

# %% [markdown]
# #### K-Means Clustering

# %%
#Finding the optimal K for KNN
coords = df[['longitude','latitude']]
distortions = []
for k in range(1,25):
    kmeansModel = KMeans(n_clusters=k)
    kmeansModel = kmeansModel.fit(coords)
    distortions.append(kmeansModel.inertia_)

# %%
#Searching for the optimal K using the elbow method
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(range(1,25), distortions, marker='o')
plt.xlabel('k')
plt.ylabel('Distortions')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
sil = []
kmax = 25
for k in range(2, kmax+1):
  kmeans = KMeans(n_clusters = k).fit(coords)
  labels = kmeans.labels_
  sil.append(silhouette_score(coords, labels, metric = 'euclidean'))

# %%
sil
# Out:
# [0.47503660711931966,
#  0.4944906151276474,
#  0.5375365853236187,
#  0.5528347531642716,
#  0.36778914169586435,
#  0.4403137305890978,
#  0.4462837826860946,
#  0.43862707564224307,
#  0.41509704022381855,
#  0.38705139195118904,
#  0.3990103432570548,
#  0.40885929253231895,
#  0.41766205060892897,
#  0.42568997826522037,
#  0.42199404845105093,
#  0.4466277086583837,
#  0.43619485778412304,
#  0.43896724549842703,
#  0.42891533850984426,
#  0.4349237553577243,
#  0.4442529440820007,
#  0.43190130472369004,
#  0.4456649561494674,
#  0.44389353469033205]

# %%
# Elbow Graph for Silhouette Score
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(range(1,25), sil[:24], marker='o')
plt.xlabel('k', fontsize = 14)
plt.ylabel('Silhouette Score', fontsize = 14)
plt.title('Silhouette Score Elbow for KMeans Clustering', fontsize = 16)
plt.show()

# %%
kmeans = KMeans(n_clusters=4, init='k-means++')
kmeans.fit(coords)
y = kmeans.labels_
print("k = 4", " silhouette_score ", silhouette_score(coords, y, metric='euclidean'))
# Out:
# k = 4  silhouette_score  0.5375365853236187

# %%
df['cluster'] = kmeans.predict(df[['longitude','latitude']])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['longitude'], df['latitude'], c=df['cluster'], cmap='viridis', marker='o', s=50)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clusters')
plt.show()

# %%
def recommend_restaurants_k(df, longitude, latitude):
    start = time.time()
    # Predict the cluster for longitude and latitude provided
    cluster = kmeans.predict(np.array([longitude,latitude]).reshape(1,-1))[0]
    print("Cluster:", cluster)
    end = time.time()
    print("Time until getting a result: ", end - start)
    # Get the best restaurant in this cluster
    return df[df['cluster']==cluster].iloc[0:10][['name', 'latitude','longitude','rating']]

# %% [markdown]
# #### K-Means - Exam User Test

# %%
#user test
user1_test=recommend_restaurants_k(df, user.longitude, user.latitude)
user1_test
# Out:
# Cluster: 2
# Time until getting a result:  0.10141801834106445
#                                      name   latitude  longitude  rating
# 87                 Fish and Chips Houston  29.543082 -95.018019     4.6
# 93                              Cao Thang  29.690305 -95.270019     4.6
# 124                 Chicharrones El Guero  29.771840 -95.233550     4.1
# 137                 Broke Da Mouth Treats  29.530695 -95.203793     4.4
# 149  Carniceria Y Taqueria Aguascalientes  29.700360 -95.277530     4.6
# 158                               Str Eat  29.655107 -95.279091     1.9
# 176               Antone’s Famous Po Boys  29.654582 -95.279335     4.0
# 225                             Gastrohub  29.652981 -95.277019     2.7
# 256                           Velvet Taco  29.654424 -95.276578     3.8
# 303              Noodle Master - Pearland  29.559540 -95.345632     4.3

# %%
# Create a map centered at a specific location
map_center = [29.7137, -95.3892]  # Latitude and longitude of Houston, Texas
my_map = folium.Map(location=map_center, zoom_start=12, width=800, height=600)

# Add a red marker at the same location
folium.Marker(
    location=map_center,
    popup='Center (Red)',
    icon=folium.Icon(color='red')
).add_to(my_map)

# Add markers to the map for each location from user reccomondation
for index, row in user1_test.iterrows():
    if not pd.isnull(row['latitude']) and not pd.isnull(row['longitude']):
        folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e311d1bb504b5f21bfe3ff82777c2288 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e311d1bb504b5f21bfe3ff82777c2288&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e311d1bb504b5f21bfe3ff82777c2288 = L.map(
#                 &quot;map_e311d1bb504b5f21bfe3ff82777c2288&quot;,
#                 {
#                     center: [29.7137, -95.3892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad86dddd21c5458f33748e2c4d58c2ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad86dddd21c5458f33748e2c4d58c2ad.addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#             var marker_d5c3e2cf21ed40e553552105c6ad8108 = L.marker(
#                 [29.7137, -95.3892],
#                 {}
#             ).addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#             var icon_d23adc8aaf26ca1452e86b5ea3989a41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d5c3e2cf21ed40e553552105c6ad8108.setIcon(icon_d23adc8aaf26ca1452e86b5ea3989a41);
#
#
#         var popup_7f5707d4030ce605cd1225f12c7679a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d14212a893c0efbcee80d2add23dcef5 = $(`&lt;div id=&quot;html_d14212a893c0efbcee80d2add23dcef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Red)&lt;/div&gt;`)[0];
#                 popup_7f5707d4030ce605cd1225f12c7679a2.setContent(html_d14212a893c0efbcee80d2add23dcef5);
#
#
#
#         marker_d5c3e2cf21ed40e553552105c6ad8108.bindPopup(popup_7f5707d4030ce605cd1225f12c7679a2)
#         ;
#
#
#
#
#             var marker_6c08b59a6c016b5e075c12fa47d400b2 = L.marker(
#                 [29.543082, -95.018019],
#                 {}
#             ).addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#         var popup_15f1ff33474bd69cee67be03e18d1e2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_616cd2119b7ce50247bb74db5c9ad441 = $(`&lt;div id=&quot;html_616cd2119b7ce50247bb74db5c9ad441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fish and Chips Houston&lt;/div&gt;`)[0];
#                 popup_15f1ff33474bd69cee67be03e18d1e2c.setContent(html_616cd2119b7ce50247bb74db5c9ad441);
#
#
#
#         marker_6c08b59a6c016b5e075c12fa47d400b2.bindPopup(popup_15f1ff33474bd69cee67be03e18d1e2c)
#         ;
#
#
#
#
#             var marker_068959afc4159abd38313dc9ce23ad9e = L.marker(
#                 [29.690305, -95.270019],
#                 {}
#             ).addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#         var popup_69ed1ef66364dbf8cc8c8682e02ca6e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a53d612d1ba4bcc24cb2f45640fdfec = $(`&lt;div id=&quot;html_0a53d612d1ba4bcc24cb2f45640fdfec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cao Thang&lt;/div&gt;`)[0];
#                 popup_69ed1ef66364dbf8cc8c8682e02ca6e7.setContent(html_0a53d612d1ba4bcc24cb2f45640fdfec);
#
#
#
#         marker_068959afc4159abd38313dc9ce23ad9e.bindPopup(popup_69ed1ef66364dbf8cc8c8682e02ca6e7)
#         ;
#
#
#
#
#             var marker_9798f0d8312e77a65f5273f87b6ebf87 = L.marker(
#                 [29.77184, -95.23355],
#                 {}
#             ).addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#         var popup_b88e842ee268a67453ea64c7885fc2ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a86952cd42fb1aa98d1b9d388e25f65a = $(`&lt;div id=&quot;html_a86952cd42fb1aa98d1b9d388e25f65a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicharrones El Guero&lt;/div&gt;`)[0];
#                 popup_b88e842ee268a67453ea64c7885fc2ce.setContent(html_a86952cd42fb1aa98d1b9d388e25f65a);
#
#
#
#         marker_9798f0d8312e77a65f5273f87b6ebf87.bindPopup(popup_b88e842ee268a67453ea64c7885fc2ce)
#         ;
#
#
#
#
#             var marker_8ebfa37454a7c3469dbfe84fbc065b85 = L.marker(
#                 [29.53069543881942, -95.2037933],
#                 {}
#             ).addTo(map_e311d1bb504b5f21bfe3ff82777c2288);
#
#
#         var popup_20aa1e6723c321eab732b2efa386e598 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec022a7d5b70693cde2e83ab9d56f053 = $(`&lt;div id=&quot;html_ec022a7d5b70693cde2e83ab9d56f053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Broke Da Mouth Tre

# %% [markdown]
# #### DBSCAN

# %%
# Select relevant features for clustering
X = df[['rating','latitude', 'longitude']]

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=2)
df['cluster'] = dbscan.fit_predict(X_scaled)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['longitude'], df['latitude'], c=df['cluster'], cmap='viridis', marker='o', s=50)
plt.title('DBSCAN Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cluster')
plt.show()

# %%
def calculate_silhouette_score(df, eps, min_samples):
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    labels = dbscan.fit_predict(df)
    silhouette = silhouette_score(df, labels)
    return silhouette

X = df[['rating', 'latitude', 'longitude']]
calculate_silhouette_score(X, 0.3, 2)
# Out:
# 0.7341030614960711

# %%
def recommend_restaurants_db(df, longitude, latitude):
    #Predict the cluster for longitude and latitude provided
    start =time.time()
    cluster = dbscan.fit_predict(np.array([longitude,latitude]).reshape(1,-1))[0]
    print("Cluster:", cluster)
    end = time.time()
    print("Time until getting a result: ", end - start)
    #Get the best restaurant in this cluster
    return df[df['cluster']==cluster].iloc[0:10][['name', 'latitude','longitude','rating']]

# %% [markdown]
# #### Exam User Test

# %%
#test
user_text_db=recommend_restaurants_db(df, user.longitude, user.latitude)
user_text_db
# Out:
# Cluster: -1
# Time until getting a result:  0.001996278762817383
#                          name   latitude  longitude  rating
# 10           Burrito District  30.097127 -95.537654     4.5
# 45       The French Fry House  29.681290 -95.319990     4.5
# 54   Jamaica Paradise Kitchen  29.988904 -95.720223     4.8
# 97                 Cup N Char  29.661013 -95.686417     4.8
# 105      Uncle Chin's Kitchen  29.760493 -95.752592     4.8
# 111        OMG Baked Potatoes  29.626883 -95.464024     4.5
# 113              Bamboo House  29.939870 -95.270260     4.4
# 124     Chicharrones El Guero  29.771840 -95.233550     4.1
# 137     Broke Da Mouth Treats  29.530695 -95.203793     4.4
# 138          Titas Taco House  29.994197 -95.250245     4.7

# %%
# Create a map centered at a specific location
map_center = [29.7137, -95.3892]  # Latitude and longitude of Houston, Texas
my_map = folium.Map(location=map_center, zoom_start=10, width=800, height=600)
# Add a red marker at the same location
folium.Marker(
    location=map_center,
    popup='Center (Red)',
    icon=folium.Icon(color='red')
).add_to(my_map)

# Add markers to the map for each location from user reccomondation
for index, row in user_text_db.iterrows():
    if not pd.isnull(row['latitude']) and not pd.isnull(row['longitude']):
        folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de120bc62b4ddc8d962b6b46a639995b {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de120bc62b4ddc8d962b6b46a639995b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de120bc62b4ddc8d962b6b46a639995b = L.map(
#                 &quot;map_de120bc62b4ddc8d962b6b46a639995b&quot;,
#                 {
#                     center: [29.7137, -95.3892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d309634010ddc8d2cbbcfb230038864c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d309634010ddc8d2cbbcfb230038864c.addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#             var marker_0c7165246ded5e4a78e4f48b5979929e = L.marker(
#                 [29.7137, -95.3892],
#                 {}
#             ).addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#             var icon_25aff7c90db28da5200e8e1543ac47b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c7165246ded5e4a78e4f48b5979929e.setIcon(icon_25aff7c90db28da5200e8e1543ac47b7);
#
#
#         var popup_bba503994686ed923198206a313306be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acf55b3f6dacb1894d769691de2d6fea = $(`&lt;div id=&quot;html_acf55b3f6dacb1894d769691de2d6fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Red)&lt;/div&gt;`)[0];
#                 popup_bba503994686ed923198206a313306be.setContent(html_acf55b3f6dacb1894d769691de2d6fea);
#
#
#
#         marker_0c7165246ded5e4a78e4f48b5979929e.bindPopup(popup_bba503994686ed923198206a313306be)
#         ;
#
#
#
#
#             var marker_8e807602552f8e4b03fbd26b1f036736 = L.marker(
#                 [30.097127, -95.5376539],
#                 {}
#             ).addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#         var popup_05eb388dcbe4de0396591b388b8a1898 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52bd2edb9a0cd5c3ed8a27c732c1722d = $(`&lt;div id=&quot;html_52bd2edb9a0cd5c3ed8a27c732c1722d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Burrito District&lt;/div&gt;`)[0];
#                 popup_05eb388dcbe4de0396591b388b8a1898.setContent(html_52bd2edb9a0cd5c3ed8a27c732c1722d);
#
#
#
#         marker_8e807602552f8e4b03fbd26b1f036736.bindPopup(popup_05eb388dcbe4de0396591b388b8a1898)
#         ;
#
#
#
#
#             var marker_0726f004e8fbc782999eddf67f5ef15d = L.marker(
#                 [29.68129, -95.31999],
#                 {}
#             ).addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#         var popup_a3f1be5b6b6e17a603b885e48840ca2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b43cc8db56c091633142d94b62af915 = $(`&lt;div id=&quot;html_3b43cc8db56c091633142d94b62af915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The French Fry House&lt;/div&gt;`)[0];
#                 popup_a3f1be5b6b6e17a603b885e48840ca2f.setContent(html_3b43cc8db56c091633142d94b62af915);
#
#
#
#         marker_0726f004e8fbc782999eddf67f5ef15d.bindPopup(popup_a3f1be5b6b6e17a603b885e48840ca2f)
#         ;
#
#
#
#
#             var marker_d27ead79ff96af5537fa72b30f1bc920 = L.marker(
#                 [29.988904, -95.720223],
#                 {}
#             ).addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#         var popup_95a3dda95a7df19d9db9be62bf77752a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a684d5cf472a853ba6b1b3e275855f34 = $(`&lt;div id=&quot;html_a684d5cf472a853ba6b1b3e275855f34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jamaica Paradise Kitchen&lt;/div&gt;`)[0];
#                 popup_95a3dda95a7df19d9db9be62bf77752a.setContent(html_a684d5cf472a853ba6b1b3e275855f34);
#
#
#
#         marker_d27ead79ff96af5537fa72b30f1bc920.bindPopup(popup_95a3dda95a7df19d9db9be62bf77752a)
#         ;
#
#
#
#
#             var marker_c5ed982f134a9b14ea8f7a670da26c97 = L.marker(
#                 [29.661013325930316, -95.68641677806724],
#                 {}
#             ).addTo(map_de120bc62b4ddc8d962b6b46a639995b);
#
#
#         var popup_10c9a2b3c50958fe0088a1367fd583a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95eee936a393687eb5dc849000a02363 = $(`&lt;div id=&quot;html_95eee936a393687eb5dc849000a02363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C

# %% [markdown]
# #### Hierarchical Clustering

# %%
# Select relevant features for clustering
X = df[['rating', 'review_count', 'longitude', 'latitude']]

# Perform hierarchical clustering
Z = linkage(X, method='ward', metric='euclidean')

# Plot dendrogram
plt.figure(figsize=(10, 8))
dendrogram(Z, labels=df['name'].values, leaf_rotation=90, leaf_font_size=10)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Restaurant')
plt.ylabel('Distance')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import cdist

def predict_location_cluster(locations, new_location, k=3):
   
    # Select relevant features for clustering
    X = locations[['latitude', 'longitude']].to_numpy()

    # Perform hierarchical clustering (Ward minimizes the sum of squared differences within all clusters).
    Z = linkage(X, method='ward')
    
    start =time.time()
    # Assign clusters to data points
    clusters = fcluster(Z, k, criterion='maxclust')
    
    # Calculate distances to cluster centroids
    centroids = np.array([np.mean(X[clusters == i], axis=0) for i in range(1, k+1)])
    distances = cdist(np.array([new_location]), centroids)

    silhoette_avg = silhouette_score(X, clusters)
    print("The silhouette score is: ", silhoette_avg)
    
    # Predict cluster for new location
    predicted_cluster = np.argmin(distances) + 1  # +1 because cluster indexing starts from 1
    end = time.time()
    print("Time until getting a result: ", end - start)
    
    #plot the cluster
    plt.figure(figsize=(8, 6))
    plt.scatter(df['longitude'], df['latitude'], c=df['cluster'], cmap='viridis', marker='o', s=50)
    plt.title('Hierarchical Clustering')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.colorbar(label='Cluster')
    plt.show()


    return predicted_cluster

# %% [markdown]
# #### Exam User Test

# %%
user = [29.7137, -95.3892]

# %%
# test user
predicted_cluster = predict_location_cluster(df, user)
print("Cluster:", predicted_cluster)

suggest_cl = df[df["cluster"] == predicted_cluster].sort_values(by=['review_count', 'rating'], ascending=False).iloc[:10][['name', 'latitude','longitude','rating']]
suggest_cl
# Out:
# The silhouette score is:  0.48564229947490073
# Time until getting a result:  0.03944110870361328
# Cluster: 1
#                            name   latitude  longitude  rating
# 274              House of Bowls  29.706182 -95.552287     4.1
# 603  San Dong Noodle House 山東麵館  29.705195 -95.555713     4.1
# 405       Golden Dumpling House  29.706415 -95.554433     4.2
# 319         Jones Fried Chicken  29.707636 -95.521141     3.5
# 201           Ohn Korean Eatery  29.707571 -95.549767     3.9
# 262                  Ishin Udon  29.707437 -95.550975     4.3
# 71             Rice To Meet You  29.706350 -95.552645     4.3
# 210                        MIAN  29.705882 -95.550631     4.3
# 342                Pepper Lunch  29.704578 -95.549009     3.5
# 212                 MDK Noodles  29.705246 -95.554402     4.2

# %%
# Create a map centered at a specific location
map_center = [29.7137, -95.3892]  # Latitude and longitude of Houston, Texas
my_map = folium.Map(location=map_center, zoom_start=12, width=800, height=600)
# Add a red marker at the same location
folium.Marker(
    location=map_center,
    popup='Center (Red)',
    icon=folium.Icon(color='red')
).add_to(my_map)

# Add markers to the map for each location from user recommendation.
for index, row in suggest_cl.iterrows():
    if not pd.isnull(row['latitude']) and not pd.isnull(row['longitude']):
        folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaaa46c7625a5fcc60c907b146e93f40 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaaa46c7625a5fcc60c907b146e93f40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaaa46c7625a5fcc60c907b146e93f40 = L.map(
#                 &quot;map_aaaa46c7625a5fcc60c907b146e93f40&quot;,
#                 {
#                     center: [29.7137, -95.3892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a0da3116cd9b153b4aa5cd1d3bcae06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a0da3116cd9b153b4aa5cd1d3bcae06.addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#             var marker_d451af6c386cb5b9cd2cd5e12ec15653 = L.marker(
#                 [29.7137, -95.3892],
#                 {}
#             ).addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#             var icon_55195f0bdeb28fcbd57cd2f028f78f63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d451af6c386cb5b9cd2cd5e12ec15653.setIcon(icon_55195f0bdeb28fcbd57cd2f028f78f63);
#
#
#         var popup_1578f4890bbc5d5862f2e001cc397da9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33a463a6a8455692d2ca524789d274ed = $(`&lt;div id=&quot;html_33a463a6a8455692d2ca524789d274ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Red)&lt;/div&gt;`)[0];
#                 popup_1578f4890bbc5d5862f2e001cc397da9.setContent(html_33a463a6a8455692d2ca524789d274ed);
#
#
#
#         marker_d451af6c386cb5b9cd2cd5e12ec15653.bindPopup(popup_1578f4890bbc5d5862f2e001cc397da9)
#         ;
#
#
#
#
#             var marker_93ba2ce74e2aa88616876f2de3780d1a = L.marker(
#                 [29.706181739333346, -95.55228678402378],
#                 {}
#             ).addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#         var popup_bb10ac724181466c48bbe88f19f84292 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b89eceb9799ed2fa3e4405d1a934562 = $(`&lt;div id=&quot;html_2b89eceb9799ed2fa3e4405d1a934562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House of Bowls&lt;/div&gt;`)[0];
#                 popup_bb10ac724181466c48bbe88f19f84292.setContent(html_2b89eceb9799ed2fa3e4405d1a934562);
#
#
#
#         marker_93ba2ce74e2aa88616876f2de3780d1a.bindPopup(popup_bb10ac724181466c48bbe88f19f84292)
#         ;
#
#
#
#
#             var marker_c17e8cc04a017bf4521a6fde9fdcd5b1 = L.marker(
#                 [29.705195, -95.555713],
#                 {}
#             ).addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#         var popup_661376db287e091b02693ff7b3a8e2fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03ad4975de2ed1ffe55dc988a15971cc = $(`&lt;div id=&quot;html_03ad4975de2ed1ffe55dc988a15971cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Dong Noodle House 山東麵館&lt;/div&gt;`)[0];
#                 popup_661376db287e091b02693ff7b3a8e2fc.setContent(html_03ad4975de2ed1ffe55dc988a15971cc);
#
#
#
#         marker_c17e8cc04a017bf4521a6fde9fdcd5b1.bindPopup(popup_661376db287e091b02693ff7b3a8e2fc)
#         ;
#
#
#
#
#             var marker_126a2cba07bfbff4a7b48aeb95cbb041 = L.marker(
#                 [29.706415, -95.554433],
#                 {}
#             ).addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#         var popup_8c1be64257b0815a130bfc28b4ad2350 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c2b6946ea80c485041600e2c3e0ccc4 = $(`&lt;div id=&quot;html_7c2b6946ea80c485041600e2c3e0ccc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Dumpling House&lt;/div&gt;`)[0];
#                 popup_8c1be64257b0815a130bfc28b4ad2350.setContent(html_7c2b6946ea80c485041600e2c3e0ccc4);
#
#
#
#         marker_126a2cba07bfbff4a7b48aeb95cbb041.bindPopup(popup_8c1be64257b0815a130bfc28b4ad2350)
#         ;
#
#
#
#
#             var marker_09d75643fc7212695b17964ebe79d579 = L.marker(
#                 [29.7076358795166, -95.5211410522461],
#                 {}
#             ).addTo(map_aaaa46c7625a5fcc60c907b146e93f40);
#
#
#         var popup_7114c510bc3e37fad871b4bdfe76cc6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50abb98bbc4144dfb8afc68453d2e350 = $(`&lt;div id=&quot;html_50abb98bbc4144dfb8afc68453d2e350&quot; style=&quot;width: 100.0%; height: 10

# %%
#!pip freeze > requirements.txt
